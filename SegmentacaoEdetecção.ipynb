# %% [markdown]
# <a href="https://colab.research.google.com/github/CyborgMx2024/Yolov8_Desafio/blob/main/SegmentacaoEdetec%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
from PIL import Image


#!yolo task=detect mode=predict model=yolov8n.pt source="/content/robo.jpeg" save=True imgsz=320 conf=0.5

# !yolo task=segment mode=predict model=/content/yolov8n-seg.pt source="/content/teste2.mp4" save=True imgsz=320 conf=0.5
# Out:
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# video 1/1 (frame 1/461) /content/teste2.mp4: 192x320 6 persons, 88.0ms
# video 1/1 (frame 2/461) /content/teste2.mp4: 192x320 6 persons, 54.3ms
# video 1/1 (frame 3/461) /content/teste2.mp4: 192x320 5 persons, 55.9ms
# video 1/1 (frame 4/461) /content/teste2.mp4: 192x320 7 persons, 53.5ms
# video 1/1 (frame 5/461) /content/teste2.mp4: 192x320 7 persons, 53.4ms
# video 1/1 (frame 6/461) /content/teste2.mp4: 192x320 6 persons, 58.1ms
# video 1/1 (frame 7/461) /content/teste2.mp4: 192x320 5 persons, 52.9ms
# video 1/1 (frame 8/461) /content/teste2.mp4: 192x320 6 persons, 55.5ms
# video 1/1 (frame 9/461) /content/teste2.mp4: 192x320 6 persons, 54.4ms
# video 1/1 (frame 10/461) /content/teste2.mp4: 192x320 6 persons, 56.7ms
# video 1/1 (frame 11/461) /content/teste2.mp4: 192x320 5 persons, 54.9ms
# ...

# %%
# !pip install moviepy
# !from moviepy.editor import VideoFileClip
from moviepy.editor import VideoFileClip

# Carrega o vídeo AVI
clip = VideoFileClip("/content/runs/segment/predict2/teste2.avi")

# Converte e salva o vídeo em MP4
clip.write_videofile("/content/convertido2.mp4", codec="libx264")

# Fecha o arquivo de vídeo após a conversão para liberar recursos
clip.close()
# Out:
# ...
# /bin/bash: line 1: from: command not found
# Moviepy - Building video /content/convertido2.mp4.
# Moviepy - Writing video /content/convertido2.mp4
# Moviepy - Done !
# Moviepy - video ready /content/convertido2.mp4

# %%
# !apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
from IPython.display import Video, display
Video = Video('/content/convertido2.mp4', width=500, height= 400)
display(Video)
# Out:
# <video src="/content/convertido2.mp4" controls  width="500"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>
